# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import requests

import sys
import random
import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://m.imdb.com/chart/top/'

headers = {'User-Agent': 'Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148'}

res = requests.get(url, headers=headers)
html_page = res.content

soup = BeautifulSoup(html_page, 'html.parser')
movies = soup.find_all('li', {'class' : 'ipc-metadata-list-summary-item sc-3f724978-0 enKyEL cli-parent'})
print(len(movies))
# Out:
# 250

# %%
def progressBar(count_value, total, start_time, end_time, suffix=''):
    bar_length = 70
    start = start_time
    filled_up_Length = int(round(bar_length* count_value / float(total)))
    percentage = round(100.0 * count_value/float(total),1)
    bar = '=' * filled_up_Length + '-' * (bar_length - filled_up_Length)
    
    elapsed_time = (end_time - start_time).total_seconds()
    
    sys.stdout.write('[%s] %s%s completed. Time: %s secs ...%s\r' %(bar, percentage, '%',elapsed_time, suffix))
    sys.stdout.flush()

# %%
top_shows = pd.DataFrame(columns=['Rank', 'Title', 'Released', 'Rating', 'Genres', 'Description'])
start_time = datetime.datetime.now()
for i in range(len(movies)):
    rank = movies[i].h3.text.split('.')[0].strip()
    title = movies[i].h3.text.split('.')[1].strip()
    released = movies[i].find('div', class_ = 'sc-43986a27-7 dBkaPT cli-title-metadata').text[:4]
    #duration = movies[i].find('div', class_ = 'sc-43986a27-7 dBkaPT cli-title-metadata').text[4:10]
    #certification = movies[i].find('div', class_ = 'sc-43986a27-7 dBkaPT cli-title-metadata').text[10:])
    rating = movies[i].find('div', class_ = 'sc-9ab53865-0 bIaPYM sc-43986a27-2 bvCMEK cli-ratings-container').text[:3]
    movie_link = 'https://m.imdb.com/'+movies[i].a.get('href')
    movie_res = requests.get(movie_link, headers=headers)
    movie_info = BeautifulSoup(movie_res.content, 'html.parser')
    movie_genre = movie_info.find('div', class_ = 'ipc-chip-list__scroller').find_all('span', class_="ipc-chip__text")
    genres = []
    for j in range(len(movie_genre)):
        genres.append(movie_genre[j].get_text())
    
    try:
        desc = movie_info.find('div', class_ = 'sc-e226b0e3-10 hbBxmX').p.span.text
    except AttributeError:
        desc = movie_info.find('div', class_ = 'sc-e226b0e3-10 kRcXhr').span.text
    
    #desc = movie_info.find('div', class_ = 'sc-e226b0e3-10 hbBxmX').p.span.text
        
    top_shows = top_shows.append({'Rank': rank,
                      'Title': title,
                      'Released' : released,
                      'Rating': rating,
                      'Genres': genres,
                      'Description': desc}, ignore_index=True)
    
    end_time = datetime.datetime.now()
    
    progressBar(i+1,len(movies), start_time, end_time)
    #print('Movie: {} inserted'.format(i+1))
# Out:
# [======================================================================] 100.0% completed. Time: 721.570836 secs ...

# %%
len(top_shows)
# Out:
# 250

# %%
top_shows
# Out:
#     Rank                     Title Released Rating  \
# 0      1  The Shawshank Redemption     1994    9.3
# 1      2             The Godfather     1972    9.2
# 2      3           The Dark Knight     2008    9.0
# 3      4    The Godfather: Part II     1974    9.0
# 4      5              12 Angry Men     1957    9.0
# ..   ...                       ...      ...    ...
# 245  246     It Happened One Night     1934    8.1
# 246  247           Pather Panchali     1955    8.2
# 247  248             The 400 Blows     1959    8.1
# 248  249                   Aladdin     1992    8.0
# 249  250        Dances with Wolves     1990    8.0
#
#                              Genres  \
# 0                           [Drama]
# 1                    [Crime, Drama]
# 2            [Action, Crime, Drama]
# 3                    [Crime, Drama]
# 4                    [Crime, Drama]
# ..                              ...
# 245               [Comedy, Romance]
# 246                         [Drama]
# ...

# %%
top_shows.to_csv('top_250_shows.csv')

# %%
top_shows.isnull().sum()
# Out:
# Rank           0
# Title          0
# Released       0
# Rating         0
# Genres         0
# Description    0
# dtype: int64

# %% [markdown]
# # Rough Work

# %%
try:
        desc = movie_info.find('div', class_ = 'sc-e226b0e3-10 hbBxmX').p.span.text
    except AttributeError:
        desc = movie_info.find('div', class_ = 'sc-e226b0e3-10 kRcXhr').span.text

# %%
start_time = datetime.datetime.now()
for i in range(26):
    time.sleep(random.random())
    end_time = datetime.datetime.now()
    
    progressBar(i,25, start_time, end_time)
# Out:
# [======================================================================] 100.0% completed. Time: 13.412554 secs ...

# %%
time.time_ns()
# Out:
# 1704279031035482000

# %%
import datetime

start_time = datetime.datetime.now()

for i in range(1,1000):
    end_time = datetime.datetime.now()
    elapsed_time = (end_time - start_time).total_seconds()
    print(f"Elapsed time : {elapsed_time}")
# Out:
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# Elapsed time : 0.0
# ...

# %%
type(elapsed_time)
# Out:
# float

# %%
print('Movie: {} inserted'.format(1))
# Out:
# Movie: 1 inserted

# %%
print('https://m.imdb.com/title/tt0111161/?ref_=chttp_i_1')
# Out:
# https://m.imdb.com/title/tt0111161/?ref_=chttp_i_1

# %%
print(movies[0].h3.text.split('.')[0].strip())
print(movies[0].h3.text.split('.')[1].strip())
print(movies[0].find('div', class_ = 'sc-43986a27-7 dBkaPT cli-title-metadata').text[:4])
print(movies[0].find('div', class_ = 'sc-43986a27-7 dBkaPT cli-title-metadata').text[4:10])
print(movies[0].find('div', class_ = 'sc-43986a27-7 dBkaPT cli-title-metadata').text[10:])
print(movies[0].find('div', class_ = 'sc-9ab53865-0 bIaPYM sc-43986a27-2 bvCMEK cli-ratings-container').text[:3])

# %%
top_shows = top_shows.append({'Rank': rank,
                  'Title': title,
                  'Released' : released,
                  'Rating': rating,
                  'Genre': Genres,
                  'Description': desc})
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Released, Rating, Genre, Description]
# Index: []
